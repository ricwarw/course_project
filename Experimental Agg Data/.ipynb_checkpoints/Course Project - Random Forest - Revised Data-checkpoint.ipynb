# %%
#import magic and libraries
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
#import data set and clean up
charity = pd.read_csv('Charity3.csv')
dummies = pd.get_dummies(charity.RenewalsOrAcq)
charity = pd.concat([charity, dummies], axis=1)
charity.drop(['Renewals'], inplace=True, axis=1)
charity.drop(['dob'], inplace=True, axis=1)
charity.drop(['RenewalsOrAcq'], inplace=True, axis=1)
charity.drop(['suburb'], inplace=True, axis=1)
charity.drop(['state'], inplace=True, axis=1)
charity = charity.dropna(subset=['age'])
charity['age'] = charity['age'].convert_objects(convert_numeric=True)
charity = charity.dropna(subset=['age'])
charity['postcode'] = charity['postcode'].astype(str)
charity.postcode.dtype
tax = pd.read_csv('2014tax2.csv')
tax['postcode'] = tax['postcode'].astype(str)
charity_new = pd.merge(charity, tax, on='postcode')
charity_new.head()
burs = pd.read_csv('abs2011combo.csv')
burs['postcode'] = burs['postcode'].astype(str)
charity_plus = pd.merge(charity_new, burs, on='postcode')
charity_plus.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-633143705abf> in <module>()
#       1 #import data set and clean up
#       2 charity = pd.read_csv('Charity3.csv')
# ----> 3 dummies = pd.get_dummies(charity.RenewalsOrAcq)
#       4 charity = pd.concat([charity, dummies], axis=1)
#       5 charity.drop(['Renewals'], inplace=True, axis=1)
#
# //anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2358                 return self[name]
#    2359             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2360                                  (type(self).__name__, name))
#    2361
#    2362     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'RenewalsOrAcq'

# %%
#have a look at the data
charity_plus.describe(include='all')
# Out:
#        postcode   num_streets  collection_amount  donation_amount  \
# count     26523  26523.000000       26523.000000     26523.000000
# unique     1728           NaN                NaN              NaN
# top        4350           NaN                NaN              NaN
# freq        230           NaN                NaN              NaN
# mean        NaN      2.883610          77.820176         3.724618
# std         NaN      2.548894          70.843846        18.707591
# min         NaN      0.000000        -414.950000      -150.000000
# 25%         NaN      1.000000          37.000000         0.000000
# 50%         NaN      2.000000          61.000000         0.000000
# 75%         NaN      3.000000         100.000000         0.000000
# max         NaN     40.000000        2123.000000      1000.000000
#
#         total_received           age      weekends    profitable  \
# count     26523.000000  26523.000000  26523.000000  26523.000000
# unique             NaN           NaN           NaN           NaN
# top                NaN           NaN           NaN           NaN
# freq               NaN           NaN           NaN           NaN
# mean         81.544794     62.458621      3.352298      0.413377
# std          70.658179     14.072699      0.871464      0.492449
# min        -500.000000      0.000000      2.000000      0.000000
# 25%          40.000000     54.000000      2.000000      0.000000
# 50%          64.000000     65.000000      4.000000      0.000000
# 75%         101.000000     72.000000      4.000000      1.000000
# max        2123.000000    103.000000      4.000000      1.000000
#
#                  Acq  Number of individuals      ...       ID_NS_OcMngr  \
# count   26523.000000           26523.000000      ...       26523.000000
# unique           NaN                    NaN      ...                NaN
# top              NaN                    NaN      ...                NaN
# freq             NaN                    NaN      ...                NaN
# mean        0.614372           10461.136033      ...          19.185575
# std         0.486752            8020.091543      ...          15.259844
# min         0.000000              44.000000      ...           0.000000
# 25%         0.000000            4794.000000      ...           8.000000
# 50%         1.000000            8363.000000      ...          15.000000
# 75%         1.000000           14224.000000      ...          26.000000
# max         1.000000           43963.000000      ...          79.000000
#
#         ID_NS_OcProf  ID_NS_OcTechTrdW  ID_NS_OcComPerS  ID_NS_OcClericAdm  \
# count   26523.000000      26523.000000     26523.000000       26523.000000
# unique           NaN               NaN              NaN                NaN
# top              NaN               NaN              NaN                NaN
# freq             NaN               NaN              NaN                NaN
# mean       22.011047         30.580930        12.587641          29.396411
# std        18.650248         28.651597        11.534480          24.691946
# min         0.000000          0.000000         0.000000           0.000000
# 25%         8.000000         11.000000         4.000000          11.000000
# 50%        18.000000         21.000000        10.000000          23.000000
# 75%        33.000000         44.000000        17.000000          43.000000
# max       110.000000        188.000000        72.000000         162.000000
#
#         ID_NS_OcSalesWk  ID_NS_OcMacOp_Driv   ID_NS_OcLab  ID_NS_OcID_NS  \
# count      26523.000000        26523.000000  26523.000000   26523.000000
# unique              NaN                 NaN           NaN            NaN
# top                 NaN                 NaN           NaN            NaN
# freq                NaN                 NaN           NaN            NaN
# mean          12.072956           15.525054     28.015044      68.304340
# std           10.675764           19.228467     29.035638      57.768867
# min            0.000000            0.000000      0.000000       0.000000
# 25%            4.000000            3.000000      9.000000      29.000000
# 50%            9.000000            9.000000     18.000000      52.000000
# 75%           17.000000           20.000000     36.000000      93.000000
# max           52.000000          136.000000    167.000000     387.000000
#
#            ID_NS_Tot
# count   26523.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean      237.678996
# std       195.882441
# min         0.000000
# 25%       102.000000
# 50%       184.000000
# 75%       318.000000
# max      1275.000000
#
# [11 rows x 1323 columns]

# %%
#Try Decision Trees
from sklearn import tree
from sklearn.cross_validation import train_test_split
from sklearn import metrics

# %%
#split data up for training
X = charity_plus.filter(regex="[^postcode]")
y = charity_plus.postcode
#y_train = np.asarray(charity_new['total_received'], dtype="|S6")
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, dtype="|S6")
# Out:
# //anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:1883: DeprecationWarning: dtype option is ignored and will be removed in 0.18.
#   DeprecationWarning)

# %%
# Create a decision tree classifier instance (start out with a small tree for interpretability)
ctree = tree.DecisionTreeClassifier(random_state=1, max_depth=2)

# %%
# Fit the decision tree classifier
#y_train = np.asarray(charity_new['total_received'], dtype="|S6")
ctree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=2,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=1, splitter='best')

# %%
# Create a feature vector
features = charity_plus.columns.tolist()

features
# Out:
# ['postcode',
#  'num_streets',
#  'collection_amount',
#  'donation_amount',
#  'total_received',
#  'age',
#  'weekends',
#  'profitable',
#  'Acq',
#  'Number of individuals',
#  'Taxable income or loss3\rno.',
#  'Taxable income or loss3\r$',
#  'Gross tax\rno.',
#  'Gross tax\r$',
#  'Medicare levy\rno.',
#  'Medicare levy\r$',
#  'Medicare levy surcharge\rno.',
#  'Medicare levy surcharge\r$',
#  'Net tax\rno.',
#  'Net tax\r$',
#  'HELP assessment debt\rno.',
#  'HELP assessment debt\r$',
#  'Salary or wages\rno.',
#  'Salary or wages\r$',
#  'Allowances earnings tips directors fees etc\rno.',
#  'Allowances earnings tips directors fees etc\r$',
#  'Employer lump sum payments amount A\rno.',
#  'Employer lump sum payments amount A\r$',
#  'Employment termination payments taxable component\rno.',
#  'Employment termination payments taxable component\r$',
#  'Australian government allowances and payments\rno.',
#  'Australian government allowances and payments\r$',
#  'Australian government pensions and allowances\rno.',
#  'Australian government pensions and allowances\r$',
#  'Australian annuities and superannuation income streams taxable component taxed element\rno.',
#  'Australian annuities and superannuation income streams taxable component taxed element\r$',
#  'Australian annuities and superannuation income streams taxable component untaxed element\rno.',
#  'Australian annuities and superannuation income streams taxable component untaxed element\r$',
#  'Gross interest\rno.',
#  'Gross interest\r$',
#  'Dividends unfranked\rno.',
#  'Dividends unfranked\r$',
#  'Dividends franked\rno.',
#  'Dividends franked\r$',
#  'Dividends franking credit\rno.',
#  'Dividends franking credit\r$',
#  'Total Income or Loss3\rno.',
#  'Total Income or Loss3\r$',
#  'Total work related car expenses\rno.',
#  'Total work related car expenses\r$',
#  'Work related travel expenses\rno.',
#  'Work related travel expenses\r$',
#  'Total work related uniform/clothing expenses\rno.',
#  'Total work related uniform/clothing expenses\r$',
#  'Total work related self education expenses\rno.',
#  'Total work related self education expenses\r$',
#  'Other work related expenses\rno.',
#  'Other work related expenses\r$',
#  'Low value pool deduction\rno.',
#  'Low value pool deduction\r$',
#  'Interest deductions\rno.',
#  'Interest deductions\r$',
#  'Dividend deductions\rno.',
#  'Dividend deductions\r$',
#  'Gifts or donations\rno.',
#  'Gifts or donations\r$',
#  'Cost of managing tax affairs\rno.',
#  'Cost of managing tax affairs\r$',
#  'Total deductions3\rno.',
#  'Total deductions3\r$',
#  'Total reportable fringe benefits amount\rno.',
#  'Total reportable fringe benefits amount\r$',
#  'Reportable employer superannuation contributions\rno.',
#  'Reportable employer superannuation contributions\r$',
#  'Net primary production distribution\rno.',
#  'Net primary production distribution\r$',
#  'Net non primary production distribution\rno.',
#  'Net non primary production distribution\r$',
#  'Share of franking credit from franked dividends\rno.',
#  'Share of franking credit from franked dividends\r$',
#  'Net PSI transferred\rno.',
#  'Net PSI transferred\r$',
#  'Deferred non-commercial business losses primary production deferred losses\rno.',
#  'Deferred non-commercial business losses primary production deferred losses\r$',
#  'Deferred non-commercial business losses non primary production deferred losses\rno.',
#  'Deferred non-commercial business losses non primary production deferred losses\r$',
#  'Capital gains net capital gain\rno.',
#  'Capital gains net capital gain\r$',
#  'Estimated tax on net capital gains\rno.',
#  'Estimated tax on net capital gains\r$',
#  'Capital gains total current year capital gains\rno.',
#  'Capital gains total current year capital gains\r$',
#  'Capital gains net capital losses carrier forward\rno.',
#  'Capital gains net capital losses carrier forward\r$',
#  'Foreign source income assessable foreign source income\rno.',
#  'Foreign source income assessable foreign source income\r$',
#  'Foreign source income other net foreign source income',
#  'Foreign source income other net foreign source income.1',
#  'Foreign source income foreign income tax offset\rno.',
#  'Foreign source income foreign income tax offset\r$',
#  'Gross rent\rno.',
#  'Gross rent\r$',
#  'Rent interest deductions\rno.',
#  'Rent interest deductions\r$',
#  'Rent capital works deductions\rno.',
#  'Rent capital works deductions\r$',
#  'Rent other rental deductions\rno.',
#  'Rent other rental deductions\r$',
#  'Net rent - profit no.',
#  'Net rent - profit $',
#  'Net rent - loss no.',
#  'Net rent - loss $',
#  'Net rent3\rno.',
#  'Net rent3\r$',
#  'Other income category 1\rno.',
#  'Other income category 1\r$',
#  'Other income category 2\rno.',
#  'Other income category 2\r$',
#  'Personal superannuation contributions\rno.',
#  'Personal superannuation contributions\r$',
#  'Other deductions\rno.',
#  'Other deductions\r$',
#  'Total business income3\rno.',
#  'Total business income3\r$',
#  'Total business expenses3\rno.',
#  'Total business expenses3\r$',
#  'Net income or loss from business\rno.',
#  'Net income or loss from business\r$',
#  'Estimated business net tax\rno.',
#  'Estimated business net tax\r$',
#  'Australian superannuation income stream tax offset\rno.',
#  'Australian superannuation income stream tax offset\r$',
#  'Net medical expenses over the threshold amount tax offset\rno.',
#  'Net medical expenses over the threshold amount tax offset\r$',
#  'Low income tax offset\rno.',
#  'Low income tax offset\r$',
#  'Mature age worker tax offset\rno.',
#  'Mature age worker tax offset\r$',
#  'Termination payment tax offset\rno.',
#  'Termination payment tax offset\r$',
#  'Tot_P_M',
#  'Tot_P_F',
#  'Tot_P_P',
#  'Age_0_4_yr_M',
#  'Age_0_4_yr_F',
#  'Age_0_4_yr_P',
#  'Age_5_14_yr_M',
#  'Age_5_14_yr_F',
#  'Age_5_14_yr_P',
#  'Age_15_19_yr_M',
#  'Age_15_19_yr_F',
#  'Age_15_19_yr_P',
#  'Age_20_24_yr_M',
#  'Age_20_24_yr_F',
#  'Age_20_24_yr_P',
#  'Age_25_34_yr_M',
#  'Age_25_34_yr_F',
#  'Age_25_34_yr_P',
#  'Age_35_44_yr_M',
#  'Age_35_44_yr_F',
#  'Age_35_44_yr_P',
#  'Age_45_54_yr_M',
#  'Age_45_54_yr_F',
#  'Age_45_54_yr_P',
#  'Age_55_64_yr_M',
#  'Age_55_64_yr_F',
#  'Age_55_64_yr_P',
#  'Age_65_74_yr_M',
#  'Age_65_74_yr_F',
#  'Age_65_74_yr_P',
#  'Age_75_84_yr_M',
#  'Age_75_84_yr_F',
#  'Age_75_84_yr_P',
#  'Age_85ov_M',
#  'Age_85ov_F',
#  'Age_85ov_P',
#  'Counted_Census_Night_home_M',
#  'Counted_Census_Night_home_F',
#  'Counted_Census_Night_home_P',
#  'Count_Census_Nt_Ewhere_Aust_M',
#  'Count_Census_Nt_Ewhere_Aust_F',
#  'Count_Census_Nt_Ewhere_Aust_P',
#  'Indigenous_psns_Aboriginal_M',
#  'Indigenous_psns_Aboriginal_F',
#  'Indigenous_psns_Aboriginal_P',
#  'Indig_psns_Torres_Strait_Is_M',
#  'Indig_psns_Torres_Strait_Is_F',
#  'Indig_psns_Torres_Strait_Is_P',
#  'Indig_Bth_Abor_Torres_St_Is_M',
#  'Indig_Bth_Abor_Torres_St_Is_F',
#  'Indig_Bth_Abor_Torres_St_Is_P',
#  'Indigenous_P_Tot_M',
#  'Indigenous_P_Tot_F',
#  'Indigenous_P_Tot_P',
#  'Birthplace_Australia_M',
#  'Birthplace_Australia_F',
#  'Birthplace_Australia_P',
#  'Birthplace_Elsewhere_M',
#  'Birthplace_Elsewhere_F',
#  'Birthplace_Elsewhere_P',
#  'Lang_spoken_home_Eng_only_M',
#  'Lang_spoken_home_Eng_only_F',
#  'Lang_spoken_home_Eng_only_P',
#  'Lang_spoken_home_Oth_Lang_M',
#  'Lang_spoken_home_Oth_Lang_F',
#  'Lang_spoken_home_Oth_Lang_P',
#  'Australian_citizen_M',
#  'Australian_citizen_F',
#  'Australian_citizen_P',
#  'Age_psns_att_educ_inst_0_4_M',
#  'Age_psns_att_educ_inst_0_4_F',
#  'Age_psns_att_educ_inst_0_4_P',
#  'Age_psns_att_educ_inst_5_14_M',
#  'Age_psns_att_educ_inst_5_14_F',
#  'Age_psns_att_educ_inst_5_14_P',
#  'Age_psns_att_edu_inst_15_19_M',
#  'Age_psns_att_edu_inst_15_19_F',
#  'Age_psns_att_edu_inst_15_19_P',
#  'Age_psns_att_edu_inst_20_24_M',
#  'Age_psns_att_edu_inst_20_24_F',
#  'Age_psns_att_edu_inst_20_24_P',
#  'Age_psns_att_edu_inst_25_ov_M',
#  'Age_psns_att_edu_inst_25_ov_F',
#  'Age_psns_att_edu_inst_25_ov_P',
#  'High_yr_schl_comp_Yr_12_eq_M',
#  'High_yr_schl_comp_Yr_12_eq_F',
#  'High_yr_schl_comp_Yr_12_eq_P',
#  'High_yr_schl_comp_Yr_11_eq_M',
#  'High_yr_schl_comp_Yr_11_eq_F',
#  'High_yr_schl_comp_Yr_11_eq_P',
#  'High_yr_schl_comp_Yr_10_eq_M',
#  'High_yr_schl_comp_Yr_10_eq_F',
#  'High_yr_schl_comp_Yr_10_eq_P',
#  'High_yr_schl_comp_Yr_9_eq_M',
#  'High_yr_schl_comp_Yr_9_eq_F',
#  'High_yr_schl_comp_Yr_9_eq_P',
#  'High_yr_schl_comp_Yr_8_belw_M',
#  'High_yr_schl_comp_Yr_8_belw_F',
#  'High_yr_schl_comp_Yr_8_belw_P',
#  'High_yr_schl_comp_D_n_g_sch_M',
#  'High_yr_schl_comp_D_n_g_sch_F',
#  'High_yr_schl_comp_D_n_g_sch_P',
#  'Count_psns_occ_priv_dwgs_M',
#  'Count_psns_occ_priv_dwgs_F',
#  'Count_psns_occ_priv_dwgs_P',
#  'Count_Persons_other_dwgs_M',
#  'Count_Persons_other_dwgs_F',
#  'Count_Persons_other_dwgs_P',
#  'Median_age_persons',
#  'Median_mortgage_repay_monthly',
#  'Median_Tot_prsnl_inc_weekly',
#  'Median_rent_weekly',
#  'Median_Tot_fam_inc_weekly',
#  'Average_num_psns_per_bedroom',
#  'Median_Tot_hhd_inc_weekly',
#  'Average_household_size',
#  'M_15_19_yr_Married',
#  'M_15_19_yr_Separated',
#  'M_15_19_yr_Divorced',
#  'M_15_19_yr_Widowed',
#  'M_15_19_yr_Never_Married',
#  'M_15_19_yr_Tot',
#  'M_20_24_yr_Married',
#  'M_20_24_yr_Separated',
#  'M_20_24_yr_Divorced',
#  'M_20_24_yr_Widowed',
#  'M_20_24_yr_Never_Married',
#  'M_20_24_yr_Tot',
#  'M_25_34_yr_Married',
#  'M_25_34_yr_Separated',
#  'M_25_34_yr_Divorced',
#  'M_25_34_yr_Widowed',
#  'M_25_34_yr_Never_Married',
#  'M_25_34_yr_Tot',
#  'M_35_44_yr_Married',
#  'M_35_44_yr_Separated',
#  'M_35_44_yr_Divorced',
#  'M_35_44_yr_Widowed',
#  'M_35_44_yr_Never_Married',
#  'M_35_44_yr_Tot',
#  'M_45_54_yr_Married',
#  'M_45_54_yr_Separated',
#  'M_45_54_yr_Divorced',
#  'M_45_54_yr_Widowed',
#  'M_45_54_yr_Never_Married',
#  'M_45_54_yr_Tot',
#  'M_55_64_yr_Married',
#  'M_55_64_yr_Separated',
#  'M_55_64_yr_Divorced',
#  'M_55_64_yr_Widowed',
#  'M_55_64_yr_Never_Married',
#  'M_55_64_yr_Tot',
#  'M_65_74_yr_Married',
#  'M_65_74_yr_Separated',
#  'M_65_74_yr_Divorced',
#  'M_65_74_yr_Widowed',
#  'M_65_74_yr_Never_Married',
#  'M_65_74_yr_Tot',
#  'M_75_84_yr_Married',
#  'M_75_84_yr_Separated',
#  'M_75_84_yr_Divorced',
#  'M_75_84_yr_Widowed',
#  'M_75_84_yr_Never_Married',
#  'M_75_84_yr_Tot',
#  'M_85ov_Married',
#  'M_85ov_Separated',
#  'M_85ov_Divorced',
#  'M_85ov_Widowed',
#  'M_85ov_Never_Married',
#  'M_85ov_Tot',
#  'M_Tot_Married',
#  'M_Tot_Separated',
#  'M_Tot_Divorced',
#  'M_Tot_Widowed',
#  'M_Tot_Never_Married',
#  'M_Tot_Tot',
#  'F_15_19_yr_Married',
#  'F_15_19_yr_Separated',
#  'F_15_19_yr_Divorced',
#  'F_15_19_yr_Widowed',
#  'F_15_19_yr_Never_Married',
#  'F_15_19_yr_Tot',
#  'F_20_24_yr_Married',
#  'F_20_24_yr_Separated',
#  'F_20_24_yr_Divorced',
#  'F_20_24_yr_Widowed',
#  'F_20_24_yr_Never_Married',
#  'F_20_24_yr_Tot',
#  'F_25_34_yr_Married',
#  'F_25_34_yr_Separated',
#  'F_25_34_yr_Divorced',
#  'F_25_34_yr_Widowed',
#  'F_25_34_yr_Never_Married',
#  'F_25_34_yr_Tot',
#  'F_35_44_yr_Married',
#  'F_35_44_yr_Separated',
#  'F_35_44_yr_Divorced',
#  'F_35_44_yr_Widowed',
#  'F_35_44_yr_Never_Married',
#  'F_35_44_yr_Tot',
#  'F_45_54_yr_Married',
#  'F_45_54_yr_Separated',
#  'F_45_54_yr_Divorced',
#  'F_45_54_yr_Widowed',
#  'F_45_54_yr_Never_Married',
#  'F_45_54_yr_Tot',
#  'F_55_64_yr_Married',
#  'F_55_64_yr_Separated',
#  'F_55_64_yr_Divorced',
#  'F_55_64_yr_Widowed',
#  'F_55_64_yr_Never_Married',
#  'F_55_64_yr_Tot',
#  'F_65_74_yr_Married',
#  'F_65_74_yr_Separated',
#  'F_65_74_yr_Divorced',
#  'F_65_74_yr_Widowed',
#  'F_65_74_yr_Never_Married',
#  'F_65_74_yr_Tot',
#  'F_75_84_yr_Married',
#  'F_75_84_yr_Separated',
#  'F_75_84_yr_Divorced',
#  'F_75_84_yr_Widowed',
#  'F_75_84_yr_Never_Married',
#  'F_75_84_yr_Tot',
#  'F_85ov_Married',
#  'F_85ov_Separated',
#  'F_85ov_Divorced',
#  'F_85ov_Widowed',
#  'F_85ov_Never_Married',
#  'F_85ov_Tot',
#  'F_Tot_Married',
#  'F_Tot_Separated',
#  'F_Tot_Divorced',
#  'F_Tot_Widowed',
#  'F_Tot_Never_Married',
#  'F_Tot_Tot',
#  'P_15_19_yr_Married',
#  'P_15_19_yr_Separated',
#  'P_15_19_yr_Divorced',
#  'P_15_19_yr_Widowed',
#  'P_15_19_yr_Never_Married',
#  'P_15_19_yr_Tot',
#  'P_20_24_yr_Married',
#  'P_20_24_yr_Separated',
#  'P_20_24_yr_Divorced',
#  'P_20_24_yr_Widowed',
#  'P_20_24_yr_Never_Married',
#  'P_20_24_yr_Tot',
#  'P_25_34_yr_Married',
#  'P_25_34_yr_Separated',
#  'P_25_34_yr_Divorced',
#  'P_25_34_yr_Widowed',
#  'P_25_34_yr_Never_Married',
#  'P_25_34_yr_Tot',
#  'P_35_44_yr_Married',
#  'P_35_44_yr_Separated',
#  'P_35_44_yr_Divorced',
#  'P_35_44_yr_Widowed',
#  'P_35_44_yr_Never_Married',
#  'P_35_44_yr_Tot',
#  'P_45_54_yr_Married',
#  'P_45_54_yr_Separated',
#  'P_45_54_yr_Divorced',
#  'P_45_54_yr_Widowed',
#  'P_45_54_yr_Never_Married',
#  'P_45_54_yr_Tot',
#  'P_55_64_yr_Married',
#  'P_55_64_yr_Separated',
#  'P_55_64_yr_Divorced',
#  'P_55_64_yr_Widowed',
#  'P_55_64_yr_Never_Married',
#  'P_55_64_yr_Tot',
#  'P_65_74_yr_Married',
#  'P_65_74_yr_Separated',
#  'P_65_74_yr_Divorced',
#  'P_65_74_yr_Widowed',
#  'P_65_74_yr_Never_Married',
#  'P_65_74_yr_Tot',
#  'P_75_84_yr_Married',
#  'P_75_84_yr_Separated',
#  'P_75_84_yr_Divorced',
#  'P_75_84_yr_Widowed',
#  'P_75_84_yr_Never_Married',
#  'P_75_84_yr_Tot',
#  'P_85ov_Married',
#  'P_85ov_Separated',
#  'P_85ov_Divorced',
#  'P_85ov_Widowed',
#  'P_85ov_Never_Married',
#  'P_85ov_Tot',
#  'P_Tot_Married',
#  'P_Tot_Separated',
#  'P_Tot_Divorced',
#  'P_Tot_Widowed',
#  'P_Tot_Never_Married',
#  'P_Tot_Tot',
#  'M_15_19_yr_Marrd_reg_marrge',
#  'M_15_19_yr_Married_de_facto',
#  'M_15_19_yr_Not_married',
#  'M_15_19_yr_Total',
#  'M_20_24_yr_Marrd_reg_marrge',
#  'M_20_24_yr_Married_de_facto',
#  'M_20_24_yr_Not_married',
#  'M_20_24_yr_Total',
#  'M_25_34_yr_Marrd_reg_marrge',
#  'M_25_34_yr_Married_de_facto',
#  'M_25_34_yr_Not_married',
#  'M_25_34_yr_Total',
#  'M_35_44_yr_Marrd_reg_marrge',
#  'M_35_44_yr_Married_de_facto',
#  'M_35_44_yr_Not_married',
#  'M_35_44_yr_Total',
#  'M_45_54_yr_Marrd_reg_marrge',
#  'M_45_54_yr_Married_de_facto',
#  'M_45_54_yr_Not_married',
#  'M_45_54_yr_Total',
#  'M_55_64_yr_Marrd_reg_marrge',
#  'M_55_64_yr_Married_de_facto',
#  'M_55_64_yr_Not_married',
#  'M_55_64_yr_Total',
#  'M_65_74_yr_Marrd_reg_marrge',
#  'M_65_74_yr_Married_de_facto',
#  'M_65_74_yr_Not_married',
#  'M_65_74_yr_Total',
#  'M_75_84_yr_Marrd_reg_marrge',
#  'M_75_84_yr_Married_de_facto',
#  'M_75_84_yr_Not_married',
#  'M_75_84_yr_Total',
#  'M_85ov_Marrd_reg_marrge',
#  'M_85ov_Married_de_facto',
#  'M_85ov_Not_married',
#  'M_85ov_Total',
#  'M_Tot_Marrd_reg_marrge',
#  'M_Tot_Married_de_facto',
#  'M_Tot_Not_married',
#  'M_Tot_Total',
#  'F_15_19_yr_Marrd_reg_marrge',
#  'F_15_19_yr_Married_de_facto',
#  'F_15_19_yr_Not_married',
#  'F_15_19_yr_Total',
#  'F_20_24_yr_Marrd_reg_marrge',
#  'F_20_24_yr_Married_de_facto',
#  'F_20_24_yr_Not_married',
#  'F_20_24_yr_Total',
#  'F_25_34_yr_Marrd_reg_marrge',
#  'F_25_34_yr_Married_de_facto',
#  'F_25_34_yr_Not_married',
#  'F_25_34_yr_Total',
#  'F_35_44_yr_Marrd_reg_marrge',
#  'F_35_44_yr_Married_de_facto',
#  'F_35_44_yr_Not_married',
#  'F_35_44_yr_Total',
#  'F_45_54_yr_Marrd_reg_marrge',
#  'F_45_54_yr_Married_de_facto',
#  'F_45_54_yr_Not_married',
#  'F_45_54_yr_Total',
#  'F_55_64_yr_Marrd_reg_marrge',
#  'F_55_64_yr_Married_de_facto',
#  'F_55_64_yr_Not_married',
#  'F_55_64_yr_Total',
#  'F_65_74_yr_Marrd_reg_marrge',
#  'F_65_74_yr_Married_de_facto',
#  'F_65_74_yr_Not_married',
#  'F_65_74_yr_Total',
#  'F_75_84_yr_Marrd_reg_marrge',
#  'F_75_84_yr_Married_de_facto',
#  'F_75_84_yr_Not_married',
#  'F_75_84_yr_Total',
#  'F_85ov_Marrd_reg_marrge',
#  'F_85ov_Married_de_facto',
#  'F_85ov_Not_married',
#  'F_85ov_Total',
#  'F_Tot_Marrd_reg_marrge',
#  'F_Tot_Married_de_facto',
#  'F_Tot_Not_married',
#  'F_Tot_Total',
#  'P_15_19_yr_Marrd_reg_marrge',
#  'P_15_19_yr_Married_de_facto',
#  'P_15_19_yr_Not_married',
#  'P_15_19_yr_Total',
#  'P_20_24_yr_Marrd_reg_marrge',
#  'P_20_24_yr_Married_de_facto',
#  'P_20_24_yr_Not_married',
#  'P_20_24_yr_Total',
#  'P_25_34_yr_Marrd_reg_marrge',
#  'P_25_34_yr_Married_de_facto',
#  'P_25_34_yr_Not_married',
#  'P_25_34_yr_Total',
#  'P_35_44_yr_Marrd_reg_marrge',
#  'P_35_44_yr_Married_de_facto',
#  'P_35_44_yr_Not_married',
#  'P_35_44_yr_Total',
#  'P_45_54_yr_Marrd_reg_marrge',
#  'P_45_54_yr_Married_de_facto',
#  'P_45_54_yr_Not_married',
#  'P_45_54_yr_Total',
#  'P_55_64_yr_Marrd_reg_marrge',
#  'P_55_64_yr_Married_de_facto',
#  'P_55_64_yr_Not_married',
#  'P_55_64_yr_Total',
#  'P_65_74_yr_Marrd_reg_marrge',
#  'P_65_74_yr_Married_de_facto',
#  'P_65_74_yr_Not_married',
#  'P_65_74_yr_Total',
#  'P_75_84_yr_Marrd_reg_marrge',
#  'P_75_84_yr_Married_de_facto',
#  'P_75_84_yr_Not_married',
#  'P_75_84_yr_Total',
#  'P_85ov_Marrd_reg_marrge',
#  'P_85ov_Married_de_facto',
#  'P_85ov_Not_married',
#  'P_85ov_Total',
#  'P_Tot_Marrd_reg_marrge',
#  'P_Tot_Married_de_facto',
#  'P_Tot_Not_married',
#  'P_Tot_Total',
#  'Aust_BP_B_OS',
#  'Aust_FO_B_OS',
#  'Aust_MO_B_OS',
#  'Aust_Both_parents_born_Aust',
#  'Aust_Birthplace_not_stated',
#  'Aust_Tot_Resp',
#  'Aust_Abor_BP_B_OS',
#  'Aust_Abor_FO_B_OS',
#  'Aust_Abor_MO_B_OS',
#  'Aust_Abor_BP_B_Aus',
#  'Aust_Abor_BP_NS',
#  'Aust_Abor_Tot_Resp',
#  'Chinese_BP_B_OS',
#  'Chinese_FO_B_OS',
#  'Chinese_MO_B_OS',
#  'Chinese_BP_B_Aus',
#  'Chinese_BP_NS',
#  'Chinese_Tot_Resp',
#  'Croatian_BP_B_OS',
#  'Croatian_FO_B_OS',
#  'Croatian_MO_B_OS',
#  'Croatian_BP_B_Aus',
#  'Croatian_BP_NS',
#  'Croatian_Tot_Resp',
#  'Dutch_BP_B_OS',
#  'Dutch_FO_B_OS',
#  'Dutch_MO_B_OS',
#  'Dutch_BP_B_Aus',
#  'Dutch_BP_NS',
#  'Dutch_Tot_Resp',
#  'English_BP_B_OS',
#  'English_FO_B_OS',
#  'English_MO_B_OS',
#  'English_BP_B_Aus',
#  'English_BP_NS',
#  'English_Tot_Resp',
#  'Filipino_BP_B_OS',
#  'Filipino_FO_B_OS',
#  'Filipino_MO_B_OS',
#  'Filipino_BP_B_Aus',
#  'Filipino_BP_NS',
#  'Filipino_Tot_Resp',
#  'French_BP_B_OS',
#  'French_FO_B_OS',
#  'French_MO_B_OS',
#  'French_BP_B_Aus',
#  'French_BP_NS',
#  'French_Tot_Resp',
#  'German_BP_B_OS',
#  'German_FO_B_OS',
#  'German_MO_B_OS',
#  'German_BP_B_Aus',
#  'German_BP_NS',
#  'German_Tot_Resp',
#  'Greek_BP_B_OS',
#  'Greek_FO_B_OS',
#  'Greek_MO_B_OS',
#  'Greek_BP_B_Aus',
#  'Greek_BP_NS',
#  'Greek_Tot_Resp',
#  'Hungarian_BP_B_OS',
#  'Hungarian_FO_B_OS',
#  'Hungarian_MO_B_OS',
#  'Hungarian_BP_B_Aus',
#  'Hungarian_BP_NS',
#  'Hungarian_Tot_Resp',
#  'Indian_BP_B_OS',
#  'Indian_FO_B_OS',
#  'Indian_MO_B_OS',
#  'Indian_BP_B_Aus',
#  'Indian_BP_NS',
#  'Indian_Tot_Resp',
#  'Irish_BP_B_OS',
#  'Irish_FO_B_OS',
#  'Irish_MO_B_OS',
#  'Irish_BP_B_Aus',
#  'Irish_BP_NS',
#  'Irish_Tot_Resp',
#  'Italian_BP_B_OS',
#  'Italian_FO_B_OS',
#  'Italian_MO_B_OS',
#  'Italian_BP_B_Aus',
#  'Italian_BP_NS',
#  'Italian_Tot_Resp',
#  'Korean_BP_B_OS',
#  'Korean_FO_B_OS',
#  'Korean_MO_B_OS',
#  'Korean_BP_B_Aus',
#  'Korean_BP_NS',
#  'Korean_Tot_Resp',
#  'Lebanese_BP_B_OS',
#  'Lebanese_FO_B_OS',
#  'Lebanese_MO_B_OS',
#  'Lebanese_BP_B_Aus',
#  'Lebanese_BP_NS',
#  'Lebanese_Tot_Resp',
#  'Macedonian_BP_B_OS',
#  'Macdonian_FO_B_OS',
#  'Macdonian_MO_B_OS',
#  'Macdonian_BP_B_Aus',
#  'Macdonian_BP_NS',
#  'Macedonian_Tot_Resp',
#  'Maltese_BP_B_OS',
#  'Maltese_FO_B_OS',
#  'Maltese_MO_B_OS',
#  'Maltese_BP_B_Aus',
#  'Maltese_BP_NS',
#  'Maltese_Tot_Resp',
#  'Maori_BP_B_OS',
#  'Maori_FO_B_OS',
#  'Maori_MO_B_OS',
#  'Maori_BP_B_Aus',
#  'Maori_BP_NS',
#  'Maori_Tot_Resp',
#  'NZ_BP_B_OS',
#  'NZ_FO_B_OS',
#  'NZ_MO_B_OS',
#  'NZ_BP_B_Aus',
#  'NZ_BP_NS',
#  'NZ_Tot_Resp',
#  'Polish_BP_B_OS',
#  'Polish_FO_B_OS',
#  'Polish_MO_B_OS',
#  'Polish_BP_B_Aus',
#  'Polish_BP_NS',
#  'Polish_Tot_Resp',
#  'Russian_BP_B_OS',
#  'Russian_FO_B_OS',
#  'Russian_MO_B_OS',
#  'Russian_BP_B_Aus',
#  'Russian_BP_NS',
#  'Russian_Tot_Resp',
#  'Scottish_BP_B_OS',
#  'Scottish_FO_B_OS',
#  'Scottish_MO_B_OS',
#  'Scottish_BP_B_Aus',
#  'Scottish_BP_NS',
#  'Scottish_Tot_Resp',
#  'Serbian_BP_B_OS',
#  'Serbian_FO_B_OS',
#  'Serbian_MO_B_OS',
#  'Serbian_BP_B_Aus',
#  'Serbian_BP_NS',
#  'Serbian_Tot_Resp',
#  'Sinhalese_BP_B_OS',
#  'Sinhalese_FO_B_OS',
#  'Sinhalese_MO_B_OS',
#  'Sinhalese_BP_B_Aus',
#  'Sinhalese_BP_NS',
#  'Sinhalese_Tot_Resp',
#  'Sth_African_BP_B_OS',
#  'Sth_African_FO_B_OS',
#  'Sth_African_MO_B_OS',
#  'Sth_Afrcan_BP_B_Aus',
#  'Sth_African_BP_NS',
#  'Sth_African_Tot_Resp',
#  'Spanish_BP_B_OS',
#  'Spanish_FO_B_OS',
#  'Spanish_MO_B_OS',
#  'Spanish_BP_B_Aus',
#  'Spanish_BP_NS',
#  'Spanish_Tot_Resp',
#  'Turkish_BP_B_OS',
#  'Turkish_FO_B_OS',
#  'Turkish_MO_B_OS',
#  'Turkish_BP_B_Aus',
#  'Turkish_BP_NS',
#  'Turkish_Tot_Resp',
#  'Vietnamese_BP_B_OS',
#  'Vietnamese_Fther_only_brn_os',
#  'Vietnamese_MO_B_OS',
#  'Vietnamese_BP_B_Aus',
#  'Vietnamese_BP_NS',
#  'Vietnamese_Tot_Resp',
#  'Welsh_BP_B_OS',
#  'Welsh_FO_B_OS',
#  'Welsh_MO_B_OS',
#  'Welsh_BP_B_Aus',
#  'Welsh_BP_NS',
#  'Welsh_Tot_Resp',
#  'Other_BP_B_OS',
#  'Other_FO_B_OS',
#  'Other_MO_B_OS',
#  'Other_BP_B_Aus',
#  'Other_BP_NS',
#  'Other_Tot_Resp',
#  'Ancestry_ns_Both_prnts_brn_os',
#  'Ancestry_ns_Fthr_only_brn_os',
#  'Ancestry_ns_Mthr_only_brn_os',
#  'Ancestry_ns_Bth_prnts_brn_Aus',
#  'Ancestry_ns_Country_birth_ns',
#  'Ancestry_ns_Tot_Resp',
#  'Tot_respnses_BP_B_OS',
#  'Tot_respnses_FO_B_OS',
#  'Tot_respnses_MO_B_OS',
#  'Tot_resp_BP_B_Aus',
#  'Tot_responses_Count_birth_ns',
#  'Tot_responses_Tot_Resp',
#  'Tot_P_BP_B_OS',
#  'Tot_P_FO_B_OS',
#  'Tot_P_MO_B_OS',
#  'Tot_P_BP_B_Aus',
#  'Tot_P_Country_birth_ns',
#  'Tot_P_Tot_Resp',
#  'SEO_Males',
#  'SEO_Females',
#  'SEO_Persons',
#  'SOL_Arabic_M',
#  'SOL_Arabic_F',
#  'SOL_Arabic_P',
#  'SOL_Assyrian_M',
#  'SOL_Assyrian_F',
#  'SOL_Assyrian_P',
#  'SOL_Aus_Indig_Lang_M',
#  'SOL_Aus_Indig_Lang_F',
#  'SOL_Aus_Indig_Lang_P',
#  'SOL_Chin_lang_Cant_M',
#  'SOL_Chin_lang_Cant_F',
#  'SOL_Chin_lang_Cant_P',
#  'SOL_Chin_lang_Mand_M',
#  'SOL_Chin_lang_Mand_F',
#  'SOL_Chin_lang_Mand_P',
#  'SOL_Chin_lang_Other_M',
#  'SOL_Chin_lang_Other_F',
#  'SOL_Chin_lang_Other_P',
#  'SOL_Chin_lang_Tot_M',
#  'SOL_Chin_lang_Tot_F',
#  'SOL_Chin_lang_Tot_P',
#  'SOL_Croatian_M',
#  'SOL_Croatian_F',
#  'SOL_Croatian_P',
#  'SOL_Dutch_M',
#  'SOL_Dutch_F',
#  'SOL_Dutch_P',
#  'SOL_French_M',
#  'SOL_French_F',
#  'SOL_French_P',
#  'SOL_German_M',
#  'SOL_German_F',
#  'SOL_German_P',
#  'SOL_Greek_M',
#  'SOL_Greek_F',
#  'SOL_Greek_P',
#  'SOL_Hungarian_M',
#  'SOL_Hungarian_F',
#  'SOL_Hungarian_P',
#  'SOL_In_Ar_Lang_Beng_M',
#  'SOL_In_Ar_Lang_Beng_F',
#  'SOL_In_Ar_Lang_Beng_P',
#  'SOL_In_Ar_Lang_Hind_M',
#  'SOL_In_Ar_Lang_Hind_F',
#  'SOL_In_Ar_Lang_Hind_P',
#  'SOL_In_Ar_Lang_Punj_M',
#  'SOL_In_Ar_Lang_Punj_F',
#  'SOL_In_Ar_Lang_Punj_P',
#  'SOL_In_Ar_Lang_Sinh_M',
#  'SOL_In_Ar_Lang_Sinh_F',
#  'SOL_In_Ar_Lang_Sinh_P',
#  'SOL_In_Ar_Lang_Urdu_M',
#  'SOL_In_Ar_Lang_Urdu_F',
#  'SOL_In_Ar_Lang_Urdu_P',
#  'SOL_In_Ar_Lang_Othr_M',
#  'SOL_In_Ar_Lang_Othr_F',
#  'SOL_In_Ar_Lang_Othr_P',
#  'SOL_In_Ar_Lang_Tot_M',
#  'SOL_In_Ar_Lang_Tot_F',
#  'SOL_In_Ar_Lang_Tot_P',
#  'SOL_Ir_Lang_Dari_M',
#  'SOL_Ir_Lang_Dari_F',
#  'SOL_Ir_Lang_Dari_P',
#  'SOL_Ir_La_Pe_excl_Da_M',
#  'SOL_Ir_La_Pe_excl_Da_F',
#  'SOL_Ir_La_Pe_excl_Da_P',
#  'SOL_Irani_Lan_Othr_M',
#  'SOL_Irani_Lan_Othr_F',
#  'SOL_Irani_Lan_Othr_P',
#  'SOL_Iran_Lan_Tot_M',
#  'SOL_Iran_Lan_Tot_F',
#  'SOL_Iran_Lan_Tot_P',
#  'SOL_Italian_M',
#  'SOL_Italian_F',
#  'SOL_Italian_P',
#  'SOL_Japanese_M',
#  'SOL_Japanese_F',
#  'SOL_Japanese_P',
#  'SOL_Khmer_M',
#  'SOL_Khmer_F',
#  'SOL_Khmer_P',
#  'SOL_Korean_M',
#  'SOL_Korean_F',
#  'SOL_Korean_P',
#  'SOL_Macedonian_M',
#  'SOL_Macedonian_F',
#  'SOL_Macedonian_P',
#  'SOL_Maltese_M',
#  'SOL_Maltese_F',
#  'SOL_Maltese_P',
#  'SOL_Polish_M',
#  'SOL_Polish_F',
#  'SOL_Polish_P',
#  'SOL_Portuguese_M',
#  'SOL_Portuguese_F',
#  'SOL_Portuguese_P',
#  'SOL_Russian_M',
#  'SOL_Russian_F',
#  'SOL_Russian_P',
#  'SOL_Samoan_M',
#  'SOL_Samoan_F',
#  'SOL_Samoan_P',
#  'SOL_Serbian_M',
#  'SOL_Serbian_F',
#  'SOL_Serbian_P',
#  'SOL_Se_As_A_L_Filipino_M',
#  'SOL_Se_As_A_L_Filipino_F',
#  'SOL_Se_As_A_L_Filipino_P',
#  'SOL_Se_As_A_L_Indon_M',
#  'SOL_Se_As_A_L_Indon_F',
#  'SOL_Se_As_A_L_Indon_P',
#  'SOL_Se_As_A_L_Tagal_M',
#  'SOL_Se_As_A_L_Tagal_F',
#  'SOL_Se_As_A_L_Tagal_P',
#  'SOL_Se_As_A_L_Othr_M',
#  'SOL_Se_As_A_L_Othr_F',
#  'SOL_Se_As_A_L_Othr_P',
#  'SOL_Se_As_A_L_Tot_M',
#  'SOL_Se_As_A_L_Tot_F',
#  'SOL_Se_As_A_L_Tot_P',
#  'SOL_Spanish_M',
#  'SOL_Spanish_F',
#  'SOL_Spanish_P',
#  'SOL_Tamil_M',
#  'SOL_Tamil_F',
#  'SOL_Tamil_P',
#  'SOL_Thai_M',
#  'SOL_Thai_F',
#  'SOL_Thai_P',
#  'SOL_Turkish_M',
#  'SOL_Turkish_F',
#  'SOL_Turkish_P',
#  'SOL_Vietnamese_M',
#  'SOL_Vietnamese_F',
#  'SOL_Vietnamese_P',
#  'SOL_Other_M',
#  'SOL_Other_F',
#  'SOL_Other_P',
#  'SOL_Tot_M',
#  'SOL_Tot_F',
#  'SOL_Tot_P',
#  'Language_spoken_home_ns_M',
#  'Language_spoken_home_ns_F',
#  'Language_spoken_home_ns_P',
#  'Total_M',
#  'Total_F',
#  'Total_P',
#  'Buddhism_M',
#  'Buddhism_F',
#  'Buddhism_P',
#  'Christianity_Anglican_M',
#  'Christianity_Anglican_F',
#  'Christianity_Anglican_P',
#  'Christianity_Asyrin_Apstlic_M',
#  'Christianity_Asyrin_Apstlic_F',
#  'Christianity_Asyrin_Apstlic_P',
#  'Christianity_Baptist_M',
#  'Christianity_Baptist_F',
#  'Christianity_Baptist_P',
#  'Christianity_Brethren_M',
#  'Christianity_Brethren_F',
#  'Christianity_Brethren_P',
#  'Christianity_Catholic_M',
#  'Christianity_Catholic_F',
#  'Christianity_Catholic_P',
#  'Christianity_Churche_Christ_M',
#  'Christianity_Churche_Christ_F',
#  'Christianity_Churche_Christ_P',
#  'Christianity_Eastrn_Orthdox_M',
#  'Christianity_Eastrn_Orthdox_F',
#  'Christianity_Eastrn_Orthdox_P',
#  'Christinty_Jehvahs_Witnses_M',
#  'Christinty_Jehvahs_Witnses_F',
#  'Christinty_Jehvahs_Witnses_P',
#  'Christianity_Lattr_day_Snts_M',
#  'Christianity_Lattr_day_Snts_F',
#  'Christianity_Lattr_day_Snts_P',
#  'Christianity_Lutheran_M',
#  'Christianity_Lutheran_F',
#  'Christianity_Lutheran_P',
#  'Christianity_Orintal_Orthdx_M',
#  'Christianity_Orintal_Orthdx_F',
#  'Christianity_Orintal_Orthdx_P',
#  'Christianity_Othr_Protestnt_M',
#  'Christianity_Othr_Protestnt_F',
#  'Christianity_Othr_Protestnt_P',
#  'Christianity_Pentecostal_M',
#  'Christianity_Pentecostal_F',
#  'Christianity_Pentecostal_P',
#  'Christinty_Prsbytrin_Refrmd_M',
#  'Christinty_Prsbytrin_Refrmd_F',
#  'Christinty_Prsbytrin_Refrmd_P',
#  'Christianity_Salvation_Army_M',
#  'Christianity_Salvation_Army_F',
#  'Christianity_Salvation_Army_P',
#  'Christnty_Sevnth_dy_Advntst_M',
#  'Christnty_Sevnth_dy_Advntst_F',
#  'Christnty_Sevnth_dy_Advntst_P',
#  'Christianity_Uniting_Church_M',
#  'Christianity_Uniting_Church_F',
#  'Christianity_Uniting_Church_P',
#  'Christianity_Christian_nfd_M',
#  'Christianity_Christian_nfd_F',
#  'Christianity_Christian_nfd_P',
#  'Christianity_Othr_Christian_M',
#  'Christianity_Othr_Christian_F',
#  'Christianity_Othr_Christian_P',
#  'Christianity_Tot_M',
#  'Christianity_Tot_F',
#  'Christianity_Tot_P',
#  'Hinduism_M',
#  'Hinduism_F',
#  'Hinduism_P',
#  'Islam_M',
#  'Islam_F',
#  'Islam_P',
#  'Judaism_M',
#  'Judaism_F',
#  'Judaism_P',
#  'Othr_Rel_Aust_Abor_Trad_Rel_M',
#  'Othr_Rel_Aust_Abor_Trad_Rel_F',
#  'Othr_Rel_Aust_Abor_Trad_Rel_P',
#  'Othr_Reln_Other_reln_groups_M',
#  'Othr_Reln_Other_reln_groups_F',
#  'Othr_Reln_Other_reln_groups_P',
#  'Other_Religions_Tot_M',
#  'Other_Religions_Tot_F',
#  'Other_Religions_Tot_P',
#  'No_Religion_M',
#  'No_Religion_F',
#  'No_Religion_P',
#  'Other_religious_affiliation_M',
#  'Other_religious_affiliation_F',
#  'Other_religious_affiliation_P',
#  'Religious_affiliation_ns_M',
#  'Religious_affiliation_ns_F',
#  'Religious_affiliation_ns_P',
#  ...]

# %%
X_train
# Out:
#        num_streets  collection_amount  donation_amount  total_received  age  \
# 11431            2               0.00            100.0          100.00   61
# 2247             1             157.00              0.0          157.00   80
# 19140            4              95.00              0.0           95.00   69
# 22612            4             125.80              0.0          125.80   52
# 11005            3              28.45              0.0           28.45   56
# 5680             1             100.00              0.0          100.00   65
# 3198             1              95.00              0.0           95.00   71
# 3402             1             162.60              0.0          162.60   70
# 21309            8               0.00             10.0           10.00   81
# 12564            3              17.00              0.0           17.00   31
# 13489            4              75.00              0.0           75.00   66
# 26145            1              74.50              0.0           74.50   79
# 25640            1             155.00              0.0          155.00   84
# 10434            2              50.00              0.0           50.00   65
# 18423            3              50.00              0.0           50.00   56
# 12663            3              75.00              0.0           75.00   51
# 1302             1              74.00              0.0           74.00   70
# 20490            7              55.05              0.0           55.05   79
# 18523            3              58.10              0.0           58.10   70
# 7049             1              60.50              0.0           60.50   47
# 1419             1             100.00              0.0          100.00   67
# 6227             2             125.00              0.0          125.00   74
# 3909             1              20.00              0.0           20.00   61
# 10778            1              53.00              0.0           53.00   52
# 19680            9              43.00              0.0           43.00   49
# 5042             1              81.00              0.0           81.00   65
# 24304            3             102.00             20.0          122.00   64
# 3393             1              47.50             12.5           60.00   68
# 2803             1              77.00              0.0           77.00   76
# 3957             1              91.30              0.0           91.30   86
# ...            ...                ...              ...             ...  ...
# 26103            1             115.00              0.0          115.00   71
# 17137            7             310.00              0.0          310.00   78
# 19433            7              34.00              0.0           34.00   58
# 24535            1              42.00              0.0           42.00   37
# 16946            3              70.00              0.0           70.00   52
# 22926            1             109.60              0.0          109.60   48
# 24477            1              57.00              0.0           57.00   17
# 4764             1             100.00              0.0          100.00   66
# 19946            7             119.80              0.0          119.80   67
# 8444             1             121.20              0.0          121.20   41
# 18900            3              30.50              0.0           30.50   63
# 2962             2             165.00              0.0          165.00   61
# 12645            3              23.00              0.0           23.00   44
# 21758            8              83.60             20.0          103.60   60
# 21780            7              35.00             10.0           45.00   32
# 25778            1              10.00              0.0           10.00   39
# 3462             1              40.00              0.0           40.00   39
# 10989            1              71.35              0.0           71.35   53
# 7751             1             115.70              0.0          115.70   72
# 16332            3               5.00              0.0            5.00   56
# 20609            7              29.00              0.0           29.00   58
# 144              9              65.00              0.0           65.00   75
# 21440            1              39.00              0.0           39.00   78
# 19279            7              87.50             12.5          100.00   40
# 7813             1              85.00              0.0           85.00   65
# 10955            1              88.00             24.0          112.00   77
# 17289            3              46.60              0.0           46.60   58
# 5192            10              15.00              0.0           15.00   38
# 12172            3              24.00              0.0           24.00   49
# 235              1             165.50              0.0          165.50   68
#
#        weekends  profitable  Acq  Number of individuals  \
# 11431         4           1    1                  22648
# 2247          4           1    0                   1044
# 19140         2           1    1                   4654
# 22612         3           1    0                   4518
# 11005         4           0    1                   2872
# 5680          4           1    1                   9682
# 3198          4           1    0                   5221
# 3402          4           1    1                   9029
# 21309         4           0    1                  15742
# 12564         2           0    0                  19849
# 13489         2           0    0                   8683
# 26145         4           0    0                  20919
# 25640         4           1    0                   5418
# 10434         4           0    1                   3322
# 18423         2           0    1                  11300
# 12663         2           0    1                  13742
# 1302          4           0    0                  32033
# 20490         4           0    1                   4452
# 18523         2           0    1                  19938
# 7049          4           0    0                  15032
# 1419          4           1    1                   8839
# 6227          4           1    1                   2268
# 3909          4           0    1                  16377
# 10778         4           0    1                  15656
# 19680         4           0    0                   6207
# 5042          4           1    0                   4847
# 24304         3           1    0                   4782
# 3393          4           0    0                   8279
# 2803          4           1    1                   1015
# 3957          4           1    0                   2417
# ...         ...         ...  ...                    ...
# 26103         4           1    1                  20919
# 17137         2           1    0                   1009
# 19433         4           0    1                   6246
# 24535         3           0    1                  23434
# 16946         2           0    0                   5084
# 22926         3           1    0                   6801
# 24477         3           0    0                   5494
# 4764          4           1    1                   5737
# 19946         4           1    0                   2461
# 8444          4           1    1                   9437
# 18900         2           0    1                   8801
# 2962          4           1    1                  12401
# 12645         2           0    1                   3823
# 21758         4           1    1                   6470
# 21780         4           0    0                   6470
# 25778         4           0    1                   4518
# 3462          4           0    1                   8704
# 10989         4           0    1                   2052
# 7751          4           1    1                   7700
# 16332         2           0    0                   1712
# 20609         4           0    0                   1369
# 144           4           0    1                   5780
# 21440         4           0    1                   1849
# 19279         4           1    0                   4859
# 7813          4           1    1                  11514
# 10955         4           1    0                   4922
# 17289         2           0    1                  10393
# 5192          4           0    1                   5796
# 12172         2           0    1                   7213
# 235           4           1    0                  15850
#
#        Taxable income or loss3\rno.    ...      ID_NS_OcMngr  ID_NS_OcProf  \
# 11431                         22648    ...                53            54
# 2247                           1044    ...                 3             8
# 19140                          4654    ...                18             8
# 22612                          4518    ...                11            23
# 11005                          2872    ...                 9             3
# 5680                           9681    ...                 8            19
# 3198                           5221    ...                 7             6
# 3402                           9029    ...                11            13
# 21309                         15742    ...                23            26
# 12564                         19849    ...                39            38
# 13489                          8683    ...                14            20
# 26145                         20919    ...                48            40
# 25640                          5418    ...                 3            20
# 10434                          3322    ...                 6             0
# 18423                         11300    ...                18            17
# 12663                         13742    ...                33            49
# 1302                          32033    ...                50           108
# 20490                          4452    ...                14            12
# 18523                         19938    ...                22            33
# 7049                          15032    ...                15            27
# 1419                           8839    ...                25            38
# 6227                           2268    ...                 5             0
# 3909                          16377    ...                10            31
# 10778                         15656    ...                23            24
# 19680                          6207    ...                16             7
# 5042                           4847    ...                 6            12
# 24304                          4782    ...                 8            17
# 3393                           8279    ...                15            13
# 2803                           1015    ...                 8             0
# 3957                           2417    ...                 3             6
# ...                             ...    ...               ...           ...
# 26103                         20919    ...                48            40
# 17137                          1009    ...                 0             0
# 19433                          6246    ...                12             8
# 24535                         23434    ...                54            54
# 16946                          5084    ...                21            15
# 22926                          6801    ...                 6            13
# 24477                          5494    ...                13            21
# 4764                           5737    ...                 3            11
# 19946                          2461    ...                 4            10
# 8444                           9437    ...                25            34
# 18900                          8801    ...                15            13
# 2962                          12401    ...                15            22
# 12645                          3823    ...                 3             4
# 21758                          6470    ...                14             4
# 21780                          6470    ...                14             4
# 25778                          4518    ...                 6             6
# 3462                           8704    ...                11            11
# 10989                          2052    ...                 5             4
# 7751                           7700    ...                20            25
# 16332                          1712    ...                 3             0
# 20609                          1369    ...                 5             3
# 144                            5780    ...                23            42
# 21440                          1849    ...                 3             3
# 19279                          4859    ...                 7             3
# 7813                          11514    ...                17            35
# 10955                          4922    ...                12             4
# 17289                         10393    ...                12             7
# 5192                           5796    ...                15             7
# 12172                          7213    ...                29            39
# 235                           15850    ...                36            37
#
#        ID_NS_OcTechTrdW  ID_NS_OcComPerS  ID_NS_OcClericAdm  ID_NS_OcSalesWk  \
# 11431                86               23                 88               40
# 2247                 11                0                  0                0
# 19140                13                6                  4                6
# 22612                 5                4                 11                3
# 11005                11                4                  5                0
# 5680                 15                4                 16                6
# 3198                 15                4                 11                8
# 3402                 44                9                 15                5
# 21309                46               19                 30               13
# 12564                55               25                 67               20
# 13489                24                7                 38               13
# 26145                65               28                 57               23
# 25640                 4                9                  3               10
# 10434                12                0                  3                5
# 18423                26               19                 21               14
# 12663                15               23                 25               20
# 1302                102               37                118               46
# 20490                 3                3                 10                6
# 18523                56               27                 35               22
# 7049                 38               22                 45               16
# 1419                 21               12                 40               11
# 6227                  4                4                  4                0
# 3909                 29               11                 33               13
# 10778                53               15                 30               13
# 19680                14                8                 20                3
# 5042                 22               13                 20                3
# 24304                10                3                 11                6
# 3393                 30                9                 25                8
# 2803                  4                0                  6                0
# 3957                  5                3                  7                3
# ...                 ...              ...                ...              ...
# 26103                65               28                 57               23
# 17137                11                0                  0                0
# 19433                22               12                 10                3
# 24535                92               42                 52               10
# 16946                14               10                 13               10
# 22926                22               10                 17               10
# 24477                 9                8                 14                5
# 4764                 20               14                 14                8
# 19946                 0                4                  3                3
# 8444                 17               10                 33               17
# 18900                46               11                 43               12
# 2962                 51               17                 33               13
# 12645                10                3                 14                0
# 21758                 8                7                 16                3
# 21780                 8                7                 16                3
# 25778                11                4                 11                4
# 3462                 43               16                 24                6
# 10989                 8                0                 14                0
# 7751                 11                4                 20                8
# 16332                 6                0                  7                0
# 20609                 4                0                  0                0
# 144                  12               12                 13                8
# 21440                 7                0                  3                3
# 19279                16                7                 15                5
# 7813                 20               15                 38               18
# 10955                14                6                  7                4
# 17289                42                6                 34               13
# 5192                  9                5                  7                6
# 12172                13                6                 14                9
# 235                  48               26                 52               23
#
#        ID_NS_OcMacOp_Driv  ID_NS_OcLab  ID_NS_OcID_NS  ID_NS_Tot
# 11431                  73           70            207        694
# 2247                    3            6             13         44
# 19140                  14           33             38        140
# 22612                   7            5             14         83
# 11005                   5           19             19         75
# 5680                    3            9             33        113
# 3198                    3           14             34        102
# 3402                   24           45             77        243
# 21309                   7           11             65        240
# 12564                  28           50            122        444
# 13489                  14           16             47        193
# 26145                  33           63             92        449
# 25640                   0            5             19         73
# 10434                   4            6             30         66
# 18423                  17           23             53        208
# 12663                  12           14             66        257
# 1302                   92           55            254        862
# 20490                   0            0             11         59
# 18523                  37           57            112        401
# 7049                   25           24             93        305
# 1419                   10           15             57        229
# 6227                    6            6             22         51
# 3909                    4           30             88        249
# 10778                  14           35             86        293
# 19680                   9            4             33        114
# 5042                   25           27             51        179
# 24304                   0            3             25         83
# 3393                   18           22             50        190
# 2803                    7            4              8         37
# 3957                    3           11             27         68
# ...                   ...          ...            ...        ...
# 26103                  33           63             92        449
# 17137                   6            9              0         26
# 19433                  11            9             69        156
# 24535                  33           67            155        559
# 16946                   3            6             30        122
# 22926                   6           15             31        130
# 24477                   3           22             22        117
# 4764                   10           13             51        144
# 19946                   3            0             10         37
# 8444                   12            8             55        211
# 18900                  22           37             66        265
# 2962                   18           30             67        266
# 12645                   4            5             23         66
# 21758                   8           48             63        171
# 21780                   8           48             63        171
# 25778                   5            7             25         79
# 3462                   25           24             79        239
# 10989                   5           15             23         74
# 7751                    0           18             32        138
# 16332                   6            7              6         35
# 20609                   3           10             13         38
# 144                     4           12             30        156
# 21440                   0            7             15         41
# 19279                   6           15             31        105
# 7813                    3           19             55        220
# 10955                   3           18             29         97
# 17289                  26           46             95        281
# 5192                   14           17             51        131
# 12172                   3           13             42        168
# 235                    13           25             93        353
#
# [19892 rows x 1322 columns]

# %%
ctree.classes_
# Out:
# array(['2000', '2008', '2010', ..., '860', '870', '880'], dtype=object)

# %%
from StringIO import StringIO
out = StringIO()
tree.export_graphviz(ctree, out_file = out)
# OUTPUT DOT LANGUAGE SCRIPTS
print out.getvalue()
# Out:
# digraph Tree {
# node [shape=box] ;
# 0 [label="X[309] <= 19251.5\ngini = 0.9986\nsamples = 19892\nvalue = [2, 1, 3 ..., 1, 15, 1]"] ;
# 1 [label="X[235] <= 2784.0\ngini = 0.9986\nsamples = 19724\nvalue = [2, 1, 3 ..., 1, 15, 1]"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="gini = 0.9986\nsamples = 19563\nvalue = [2, 1, 3 ..., 1, 15, 1]"] ;
# 1 -> 2 ;
# 3 [label="gini = 0.0\nsamples = 161\nvalue = [0, 0, 0 ..., 0, 0, 0]"] ;
# 1 -> 3 ;
# 4 [label="gini = 0.0\nsamples = 168\nvalue = [0, 0, 0 ..., 0, 0, 0]"] ;
# 0 -> 4 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# }

# %%
out.getvalue()
# Out:
# 'digraph Tree {\nnode [shape=box] ;\n0 [label="X[309] <= 19251.5\\ngini = 0.9986\\nsamples = 19892\\nvalue = [2, 1, 3 ..., 1, 15, 1]"] ;\n1 [label="X[235] <= 2784.0\\ngini = 0.9986\\nsamples = 19724\\nvalue = [2, 1, 3 ..., 1, 15, 1]"] ;\n0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;\n2 [label="gini = 0.9986\\nsamples = 19563\\nvalue = [2, 1, 3 ..., 1, 15, 1]"] ;\n1 -> 2 ;\n3 [label="gini = 0.0\\nsamples = 161\\nvalue = [0, 0, 0 ..., 0, 0, 0]"] ;\n1 -> 3 ;\n4 [label="gini = 0.0\\nsamples = 168\\nvalue = [0, 0, 0 ..., 0, 0, 0]"] ;\n0 -> 4 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;\n}'

# %%
X = charity_plus.filter(regex="[^total_received|^collection_amount|^donation_amount|^profitable]")

# %%
y = np.asarray(charity_plus['profitable'], dtype="|S6")

# %%
from sklearn.ensemble import RandomForestClassifier
rfclf = RandomForestClassifier(n_estimators=10, max_features='log2', oob_score=True, random_state=1)
rfclf.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=True, random_state=1, verbose=0, warm_start=False)

# %%
rfclf.oob_score_
# Out:
# 0.57157938393092789

# %%
from sklearn.linear_model import LogisticRegression
X = charity_plus.filter(regex="[^total_received|^collection_amount|^donation_amount|^profitable]")
y = charity_plus.profitable
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
logreg = LogisticRegression()
logreg.fit(X_train, y_train)

y_pred_class = logreg.predict(X_test)
from sklearn import metrics
print metrics.r2_score(y_test, y_pred_class)
# Out:
# -0.652744837231
