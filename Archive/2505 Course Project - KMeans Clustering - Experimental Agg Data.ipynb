# %%
#import magic and libraries
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
#import data set and clean up
charity = pd.read_csv('Charity.csv')
dummies = pd.get_dummies(charity.RenewalsOrAcq)
charity = pd.concat([charity, dummies], axis=1)
charity.drop(['Renewals'], inplace=True, axis=1)
charity.drop(['dob'], inplace=True, axis=1)
charity.drop(['RenewalsOrAcq'], inplace=True, axis=1)
charity.drop(['suburb'], inplace=True, axis=1)
charity.drop(['state'], inplace=True, axis=1)
charity = charity.dropna(subset=['age'])
charity['age'] = charity['age'].convert_objects(convert_numeric=True)
charity = charity.dropna(subset=['age'])
charity['postcode'] = charity['postcode'].astype(str)
charity.postcode.dtype
tax = pd.read_csv('2014tax2.csv')
tax['postcode'] = tax['postcode'].astype(str)
charity_new = pd.merge(charity, tax, on='postcode')
burs = pd.read_csv('abs2011combo.csv')
burs['postcode'] = charity_new['postcode'].astype(str)
charity_plus = pd.merge(charity_new, burs, on='postcode')
charity_plus.head()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:11: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   postcode  num_streets  collection_amount  donation_amount  total_received  \
# 0      801            2             315.00                0          315.00
# 1      801            2             315.00                0          315.00
# 2      801            6             303.55                0          303.55
# 3      801            6             303.55                0          303.55
# 4      804            4             250.00                0          250.00
#
#    age  gender  weekends  profitable  Acq    ...      ID_NS_OcMngr  \
# 0   72       0         4           1    0    ...                54
# 1   72       0         4           1    0    ...                 0
# 2   65       0         4           1    1    ...                54
# 3   65       0         4           1    1    ...                 0
# 4   80       0         4           1    0    ...                 6
#
#    ID_NS_OcProf  ID_NS_OcTechTrdW  ID_NS_OcComPerS  ID_NS_OcClericAdm  \
# 0            45                18               30                 31
# 1             4                 0                4                  3
# 2            45                18               30                 31
# 3             4                 0                4                  3
# 4            16                 3                4                 11
#
#    ID_NS_OcSalesWk  ID_NS_OcMacOp_Driv  ID_NS_OcLab  ID_NS_OcID_NS  ID_NS_Tot
# 0               29                   0           29            130        366
# 1                0                   3            0              0         14
# 2               29                   0           29            130        366
# 3                0                   3            0              0         14
# 4                8                   0            4             34         86
#
# [5 rows x 1204 columns]

# %%
#have a look at the data
charity_new.describe(include='all')
# Out:
#        postcode   num_streets  collection_amount  donation_amount  \
# count     26537  26537.000000       26537.000000     26537.000000
# unique     1734           NaN                NaN              NaN
# top        4350           NaN                NaN              NaN
# freq        230           NaN                NaN              NaN
# mean        NaN      2.884049          77.894208         3.726344
# std         NaN      2.549009          70.930426        18.705276
# min         NaN      0.000000        -414.950000      -150.000000
# 25%         NaN      1.000000          37.000000         0.000000
# 50%         NaN      2.000000          61.000000         0.000000
# 75%         NaN      3.000000         100.000000         0.000000
# max         NaN     40.000000        2123.000000      1000.000000
#
#         total_received           age        gender      weekends  \
# count     26537.000000  26537.000000  26537.000000  26537.000000
# unique             NaN           NaN           NaN           NaN
# top                NaN           NaN           NaN           NaN
# freq               NaN           NaN           NaN           NaN
# mean         81.620552     62.462223      0.653993      3.352640
# std          70.744762     14.071706      0.475705      0.871361
# min        -500.000000      0.000000      0.000000      2.000000
# 25%          40.000000     54.000000      0.000000      2.000000
# 50%          64.000000     65.000000      1.000000      4.000000
# 75%         101.050000     72.000000      1.000000      4.000000
# max        2123.000000    103.000000      1.000000      4.000000
#
#           profitable           Acq         ...          avg tax income  \
# count   26537.000000  26537.000000         ...            26537.000000
# unique           NaN           NaN         ...                     NaN
# top              NaN           NaN         ...                     NaN
# freq             NaN           NaN         ...                     NaN
# mean        0.413687      0.614237         ...            70939.685321
# std         0.492503      0.486784         ...            18500.218047
# min         0.000000      0.000000         ...            43815.137040
# 25%         0.000000      0.000000         ...            59571.218630
# 50%         0.000000      1.000000         ...            65394.070260
# 75%         1.000000      1.000000         ...            76169.923410
# max         1.000000      1.000000         ...           244900.912400
#
#         avg gross tax paid  avg net tax paid     avg salary   no pensions  \
# count         26537.000000      26537.000000   26537.000000  26537.000000
# unique                 NaN               NaN            NaN           NaN
# top                    NaN               NaN            NaN           NaN
# freq                   NaN               NaN            NaN           NaN
# mean          16065.531250      16455.509683   64908.680466    220.185477
# std            7449.238532       7642.706453   12039.629806    182.058407
# min            6350.877778       6268.537037   36581.158420      0.000000
# 25%           11663.791050      11967.027250   56707.959890     93.000000
# 50%           13801.708760      14161.877470   62079.569580    171.000000
# 75%           17722.579260      18308.375090   70677.676200    301.000000
# max           91110.850930      92997.553970  139507.241800   1077.000000
#
#          avg pension     avg income  no donations  value donations  \
# count   26537.000000   26537.000000  26537.000000     26537.000000
# unique           NaN            NaN           NaN              NaN
# top              NaN            NaN           NaN              NaN
# freq             NaN            NaN           NaN              NaN
# mean     7783.900419   74130.960791   4438.436937   2176361.343181
# std       802.555250   19318.228342   3438.498276   2646848.330089
# min         0.000000   45580.474070     15.000000      2532.000000
# 25%      7360.438202   62471.509520   1967.000000    688038.000000
# 50%      7788.891304   68325.239040   3630.000000   1581155.000000
# 75%      8180.023256   79465.611680   6237.000000   2836421.000000
# max     32128.666670  261782.319000  19123.000000  41384748.000000
#
#         avg donation value
# count         26537.000000
# unique                 NaN
# top                    NaN
# freq                   NaN
# mean            520.466051
# std             683.950866
# min             109.177419
# 25%             296.293056
# 50%             365.436559
# 75%             515.263736
# max           21706.094200
#
# [11 rows x 21 columns]

# %%
#K means clustering
from sklearn.cluster import KMeans

np.random.seed(0)

est = KMeans(n_clusters=4, init='random')
est.fit(charity_new)
y_kmeans = est.predict(charity_new)

# %%
#plot the clusters
colors = np.array(['#FF0054','#FBD039','#23C2BC','#0066ff'])
plt.figure()
charity_new.plot(kind='scatter', x='avg income', y='total_received',c=colors[y_kmeans])

# %%
est.cluster_centers_
# Out:
# array([[  2.96246635e+03,   1.94230769e+00,   1.14996875e+02,
#           1.25860577e+01,   1.27582933e+02,   6.60288462e+01,
#           6.82692308e-01,   3.91346154e+00,   6.10576923e-01,
#           7.35576923e-01,   1.08334856e+04,   1.48006913e+05,
#           4.84536727e+04,   4.96764431e+04,   1.00586051e+05,
#           1.06975962e+02,   8.76003253e+03,   1.56702098e+05,
#           4.77169712e+03,   2.25198388e+07,   5.49853247e+03],
#        [  3.44983039e+03,   2.60455390e+00,   8.99086199e+01,
#           5.21340613e+00,   9.51220260e+01,   6.20585502e+01,
#           6.55204461e-01,   3.32946097e+00,   4.91635688e-01,
#           6.11059480e-01,   2.15132914e+04,   9.14862352e+04,
#           2.43448358e+04,   2.50085417e+04,   7.72676323e+04,
#           4.04276487e+02,   7.90580983e+03,   9.56155863e+04,
#           9.51065195e+03,   6.56930162e+06,   1.08562337e+03],
#        [  3.88709613e+03,   2.32959376e+00,   8.07849362e+01,
#           3.81888758e+00,   8.46038238e+01,   6.19750827e+01,
#           6.53519131e-01,   3.27822390e+00,   4.35994332e-01,
#           6.19272556e-01,   1.55369152e+04,   7.49474088e+04,
#           1.75454732e+04,   1.80025549e+04,   6.85168430e+04,
#           3.18691781e+02,   7.71181792e+03,   7.82163243e+04,
#           6.61820430e+03,   2.97280910e+06,   5.45268778e+02],
#        [  4.24484270e+03,   3.23368769e+00,   7.41988064e+01,
#           3.35543319e+00,   7.75542396e+01,   6.27328920e+01,
#           6.53701700e-01,   3.38850341e+00,   3.88376090e-01,
#           6.10350754e-01,   6.19786867e+03,   6.49441693e+04,
#           1.37047225e+04,   1.40100034e+04,   6.07982165e+04,
#           1.43365332e+02,   7.79313144e+03,   6.78922080e+04,
#           2.56416137e+03,   8.75873065e+05,   3.63760603e+02]])

# %%
from sklearn import decomposition

X = charity_new.filter(regex="[^total_received|^collection_amount|^donation_amount]")
y = charity_new.total_received

pca = decomposition.PCA(n_components=2)
X_r = pca.fit_transform(X)
target_names = charity_new.total_received

plt.figure()
for c, i, target_name in zip("rgb", [0, 1, 2], target_names):
    plt.scatter(X_r[y <= i, 0], X_r[y > i, 1], c=c, label=target_name)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:12: FutureWarning: in the future, boolean array-likes will be handled as a boolean array index

# %%
pca = decomposition.PCA(n_components=3)
pca.fit(X)
decomposition.PCA(copy=True, n_components=3, whiten=False)
print(pca.explained_variance_ratio_)
# Out:
# [ 0.98472466  0.01215417  0.00167454]

# %%
plt.cla()
plt.plot(pca.explained_variance_ratio_)
plt.title('Variance explained by each principal component')
plt.ylabel(' % Variance Explained')
plt.xlabel('Principal component')

# %%
#Try Decision Trees
from sklearn import tree
from sklearn.cross_validation import train_test_split
from sklearn import metrics

# %%
#split data up for training
charity = d['Survived'].copy(deep=True)
del d['Survived']

d

# %%
y = charity.array('total_received')
print y

# %%
X = charity
#X.drop('total_received', axis=1, inplace=True)
#X.drop('collection_amount', axis=1, inplace=True)
#X.drop('donation_amount', axis=1, inplace=True)
#y = X.total_received()
X.describe(include='all')

# %%
#PCA Analysis
from mpl_toolkits.mplot3d import Axes3D

from sklearn import decomposition
from sklearn import datasets

pca = decomposition.PCA(n_components=1)
X_r = pca.fit_transform(X)

y = charity.total_received()

plt.figure()
for c, i, target_name in zip("rgb", [0, 1, 2], target_names):
    plt.scatter(X_r[y == i, 0], X_r[y == i, 1], c=c, label=target_name)
plt.legend()
plt.title('PCA(2 components) of IRIS dataset')

# %%
from sklearn import svm
from sklearn.datasets import samples_generator
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.pipeline import Pipeline
# generate some data to play with
#X, y = samples_generator.make_classification(
# n_informative=5, n_redundant=0, random_state=42)
# ANOVA SVM-C
#anova_filter = SelectKBest(f_regression, k=5)
#clf = svm.SVC(kernel='linear')
#anova_svm = Pipeline([('anova', anova_filter), ('svc', clf)])
>>> # You can set the parameters using the names issued
>>> # For instance, fit using a k of 10 in the SelectKBest
>>> # and a parameter 'C' of the svm
>>> anova_svm.set_params(anova__k=10, svc__C=.1).fit(X, y)
...                                              
Pipeline(steps=[...])
>>> prediction = anova_svm.predict(X)
>>> anova_svm.score(X, y)                        
0.77...
>>> # getting the selected features chosen by anova_filter
>>> anova_svm.named_steps['anova'].get_support()
... 
array([ True,  True,  True, False, False,  True, False,  True,  True, True,
       False, False,  True, False,  True, False, False, False, False,
       True], dtype=bool)
