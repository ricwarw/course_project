# %%
#import magic and libraries
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
#import data set and clean up
charity = pd.read_csv('Charity.csv')
dummies = pd.get_dummies(charity.RenewalsOrAcq)
charity = pd.concat([charity, dummies], axis=1)
charity.drop(['Renewals'], inplace=True, axis=1)
charity.drop(['dob'], inplace=True, axis=1)
charity.drop(['RenewalsOrAcq'], inplace=True, axis=1)
charity.drop(['suburb'], inplace=True, axis=1)
charity.drop(['state'], inplace=True, axis=1)
charity = charity.dropna(subset=['age'])
charity['age'] = charity['age'].convert_objects(convert_numeric=True)
charity = charity.dropna(subset=['age'])
charity['postcode'] = charity['postcode'].astype(str)
charity.postcode.dtype
tax = pd.read_csv('2014tax.csv')
tax['postcode'] = tax['postcode'].astype(str)
charity_new = pd.merge(charity, tax, on='postcode')
charity_new.head()
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:11: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   postcode  num_streets  collection_amount  donation_amount  total_received  \
# 0      801            2             315.00                0          315.00
# 1      801            6             303.55                0          303.55
# 2      804            4             250.00                0          250.00
# 3      804            2              28.60               50           78.60
# 4      810            2             521.50                0          521.50
#
#    age  weekends  Acq  Number of individuals  Taxable income or loss3\rno.  \
# 0   72         4    0                   1201                          1201
# 1   65         4    1                   1201                          1201
# 2   80         4    0                    289                           289
# 3   57         4    0                    289                           289
# 4   67         4    1                  16956                         16956
#
#                  ...                  \
# 0                ...
# 1                ...
# 2                ...
# 3                ...
# 4                ...
#
#    Australian superannuation income stream tax offset\rno.  \
# 0                                                 43
# 1                                                 43
# 2                                                 18
# 3                                                 18
# 4                                                453
#
#    Australian superannuation income stream tax offset\r$  \
# 0                                             193542
# 1                                             193542
# 2                                              58981
# 3                                              58981
# 4                                            1377814
#
#    Net medical expenses over the threshold amount tax offset\rno.  \
# 0                                                 16
# 1                                                 16
# 2                                                  5
# 3                                                  5
# 4                                                187
#
#    Net medical expenses over the threshold amount tax offset\r$  \
# 0                                               7159
# 1                                               7159
# 2                                               3038
# 3                                               3038
# 4                                             116847
#
#    Low income tax offset\rno.  Low income tax offset\r$  \
# 0                         555                    166980
# 1                         555                    166980
# 2                         128                     38514
# 3                         128                     38514
# 4                        9536                   2842196
#
#    Mature age worker tax offset\rno.  Mature age worker tax offset\r$  \
# 0                                 89                            37132
# 1                                 89                            37132
# 2                                 29                            12554
# 3                                 29                            12554
# 4                                930                           382016
#
#    Termination payment tax offset\rno.  Termination payment tax offset\r$
# 0                                   52                             281508
# 1                                   52                             281508
# 2                                   12                              35432
# 3                                   12                              35432
# 4                                  497                             866774
#
# [5 rows x 139 columns]

# %%
#have a look at the data
charity_new.describe(include='all')
# Out:
#        postcode   num_streets  collection_amount  donation_amount  \
# count     26537  26537.000000       26537.000000     26537.000000
# unique     1734           NaN                NaN              NaN
# top        4350           NaN                NaN              NaN
# freq        230           NaN                NaN              NaN
# mean        NaN      2.884049          77.894208         3.726344
# std         NaN      2.549009          70.930426        18.705276
# min         NaN      0.000000        -414.950000      -150.000000
# 25%         NaN      1.000000          37.000000         0.000000
# 50%         NaN      2.000000          61.000000         0.000000
# 75%         NaN      3.000000         100.000000         0.000000
# max         NaN     40.000000        2123.000000      1000.000000
#
#         total_received           age      weekends           Acq  \
# count     26537.000000  26537.000000  26537.000000  26537.000000
# unique             NaN           NaN           NaN           NaN
# top                NaN           NaN           NaN           NaN
# freq               NaN           NaN           NaN           NaN
# mean         81.620552     62.462223      3.352640      0.614237
# std          70.744762     14.071706      0.871361      0.486784
# min        -500.000000      0.000000      2.000000      0.000000
# 25%          40.000000     54.000000      2.000000      0.000000
# 50%          64.000000     65.000000      4.000000      1.000000
# 75%         101.050000     72.000000      4.000000      1.000000
# max        2123.000000    103.000000      4.000000      1.000000
#
#         Number of individuals  Taxable income or loss3\rno.  \
# count            26537.000000                  26537.000000
# unique                    NaN                           NaN
# top                       NaN                           NaN
# freq                      NaN                           NaN
# mean             10456.301956                  10456.292987
# std               8020.746498                   8020.741996
# min                 44.000000                     44.000000
# 25%               4794.000000                   4794.000000
# 50%               8363.000000                   8363.000000
# 75%              14224.000000                  14224.000000
# max              43963.000000                  43963.000000
#
#                       ...                  \
# count                 ...
# unique                ...
# top                   ...
# freq                  ...
# mean                  ...
# std                   ...
# min                   ...
# 25%                   ...
# 50%                   ...
# 75%                   ...
# max                   ...
#
#         Australian superannuation income stream tax offset\rno.  \
# count                                        26537.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           251.321137
# std                                            265.953509
# min                                              0.000000
# 25%                                             94.000000
# 50%                                            189.000000
# 75%                                            310.000000
# max                                           2112.000000
#
#         Australian superannuation income stream tax offset\r$  \
# count                                        26537.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                        731378.532200
# std                                         893770.819558
# min                                              0.000000
# 25%                                         236146.000000
# 50%                                         524541.000000
# 75%                                         912825.000000
# max                                        7374470.000000
#
#         Net medical expenses over the threshold amount tax offset\rno.  \
# count                                        26537.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                           299.632023
# std                                            243.638580
# min                                              0.000000
# 25%                                            117.000000
# 50%                                            242.000000
# 75%                                            423.000000
# max                                           1304.000000
#
#         Net medical expenses over the threshold amount tax offset\r$  \
# count                                        26537.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                        232156.240494
# std                                         195869.231079
# min                                              0.000000
# 25%                                          85421.000000
# 50%                                         182450.000000
# 75%                                         328156.000000
# max                                        1266913.000000
#
#         Low income tax offset\rno.  Low income tax offset\r$  \
# count                 26537.000000              26537.000000
# unique                         NaN                       NaN
# top                            NaN                       NaN
# freq                           NaN                       NaN
# mean                   6549.549798            2098431.845687
# std                    5193.632757            1659707.414589
# min                      28.000000               9657.000000
# 25%                    2996.000000             948576.000000
# 50%                    5056.000000            1614086.000000
# 75%                    8891.000000            2846496.000000
# max                   29621.000000            9363536.000000
#
#         Mature age worker tax offset\rno.  Mature age worker tax offset\r$  \
# count                        26537.000000                     26537.000000
# unique                                NaN                              NaN
# top                                   NaN                              NaN
# freq                                  NaN                              NaN
# mean                           880.500773                    374612.730037
# std                            657.578799                    282385.944243
# min                              4.000000                      1557.000000
# 25%                            420.000000                    177776.000000
# 50%                            696.000000                    296472.000000
# 75%                           1207.000000                    510166.000000
# max                           3793.000000                   1636367.000000
#
#         Termination payment tax offset\rno.  Termination payment tax offset\r$
# count                          26537.000000                       26537.000000
# unique                                  NaN                                NaN
# top                                     NaN                                NaN
# freq                                    NaN                                NaN
# mean                             372.813958                     1278682.665034
# std                              340.574985                     1016244.859706
# min                                1.000000                          10.000000
# 25%                              146.000000                      522753.000000
# 50%                              288.000000                     1035083.000000
# 75%                              481.000000                     1823559.000000
# max                             2396.000000                     6033791.000000
#
# [11 rows x 139 columns]

# %%
#K means clustering
from sklearn.cluster import KMeans

np.random.seed(0)

est = KMeans(n_clusters=4, init='random')
est.fit(charity_new)
y_kmeans = est.predict(charity_new)

# %%
#plot the clusters
colors = np.array(['#FF0054','#FBD039','#23C2BC','#0066ff'])
plt.figure()
charity_new.plot(kind='scatter', x='donation_amount', y='total_received',c=colors[y_kmeans])

# %%
from sklearn import decomposition

X = charity_new.filter(regex="[^total_received|^collection_amount|^donation_amount]")
y = charity_new.total_received

pca = decomposition.PCA(n_components=2)
X_r = pca.fit_transform(X)
target_names = charity_new.total_received

plt.figure()
for c, i, target_name in zip("rgb", [0, 1, 2], target_names):
    plt.scatter(X_r[y <= i, 0], X_r[y > i, 1], c=c, label=target_name)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:12: FutureWarning: in the future, boolean array-likes will be handled as a boolean array index

# %%
pca = decomposition.PCA(n_components=3)
pca.fit(X)
decomposition.PCA(copy=True, n_components=3, whiten=False)
print(pca.explained_variance_ratio_)
# Out:
# [ 0.98472466  0.01215417  0.00167454]

# %%
plt.cla()
plt.plot(pca.explained_variance_ratio_)
plt.title('Variance explained by each principal component')
plt.ylabel(' % Variance Explained')
plt.xlabel('Principal component')

# %%
#Try Decision Trees
from sklearn import tree
from sklearn.cross_validation import train_test_split
from sklearn import metrics

# %%
#split data up for training
charity = d['Survived'].copy(deep=True)
del d['Survived']

d

# %%
y = charity.array('total_received')
print y

# %%
X = charity
#X.drop('total_received', axis=1, inplace=True)
#X.drop('collection_amount', axis=1, inplace=True)
#X.drop('donation_amount', axis=1, inplace=True)
#y = X.total_received()
X.describe(include='all')

# %%
#PCA Analysis
from mpl_toolkits.mplot3d import Axes3D

from sklearn import decomposition
from sklearn import datasets

pca = decomposition.PCA(n_components=1)
X_r = pca.fit_transform(X)

y = charity.total_received()

plt.figure()
for c, i, target_name in zip("rgb", [0, 1, 2], target_names):
    plt.scatter(X_r[y == i, 0], X_r[y == i, 1], c=c, label=target_name)
plt.legend()
plt.title('PCA(2 components) of IRIS dataset')

# %%
from sklearn import svm
from sklearn.datasets import samples_generator
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.pipeline import Pipeline
# generate some data to play with
#X, y = samples_generator.make_classification(
# n_informative=5, n_redundant=0, random_state=42)
# ANOVA SVM-C
#anova_filter = SelectKBest(f_regression, k=5)
#clf = svm.SVC(kernel='linear')
#anova_svm = Pipeline([('anova', anova_filter), ('svc', clf)])
>>> # You can set the parameters using the names issued
>>> # For instance, fit using a k of 10 in the SelectKBest
>>> # and a parameter 'C' of the svm
>>> anova_svm.set_params(anova__k=10, svc__C=.1).fit(X, y)
...                                              
Pipeline(steps=[...])
>>> prediction = anova_svm.predict(X)
>>> anova_svm.score(X, y)                        
0.77...
>>> # getting the selected features chosen by anova_filter
>>> anova_svm.named_steps['anova'].get_support()
... 
array([ True,  True,  True, False, False,  True, False,  True,  True, True,
       False, False,  True, False,  True, False, False, False, False,
       True], dtype=bool)
